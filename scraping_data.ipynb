# %% [markdown]
# **Analisis Sentimen Ulasan Pengguna pada Aplikasi Exchange Stockbit**

# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
from google_play_scraper import reviews_all, Sort

# Mengambil semua ulasan dari aplikasi Stockbit
scrapreview = reviews_all(
    'com.stockbit.android',           
    lang='id',              
    country='id',           
    sort=Sort.MOST_RELEVANT, 
    count=1000              
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('Stockbit_ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review']) 
    for review in scrapreview:
        writer.writerow([review['content']])
